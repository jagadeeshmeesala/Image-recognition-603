# %% [markdown]
# # MNIST

# %%
# !pip3 install keras
import numpy
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2zD, MaxPooling2D
from keras import backend as K
import matplotlib.pyplot as plt


# the data, split between train and test sets
from keras.utils import np_utils
from matplotlib import pyplot
from sklearn.model_selection import KFold
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.optimizers import SGD

# import MNIST dataset
from keras.datasets import mnist

# %%
def input_data():

    (X_train, y_train), (X_test, y_test) = mnist.load_data()

    # Reshape to be samples*pixels*width*height
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
    X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')


    # One hot Code
    # https://machinelearningmastery.com/how-to-one-hot-encode-sequence-data-in-python/
    y_train = np_utils.to_categorical(y_train)
    y_test = np_utils.to_categorical(y_test)
    num_classes = y_test.shape[1]

    # convert from integers to floats
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    # normalize to range [0, 1]
    X_train = (X_train / 255.0)
    X_test = (X_test / 255.0)

    return X_test, y_test, X_train, y_train

# %%
# Flatten the images.
# Flatten each 28x28 image into a 784 dimensional vector

def create_model():
    # Create model
    # Building CNN
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
    
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))

    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))

    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())

    model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))

    model.add(Dense(10, activation='softmax'))

    model.summary()

    # compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
# -------when you dont want to evaluate the model-------------
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200)

# # Final evaluation of the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Large CNN Error: %.2f%%" % (100-scores[1]*100))

# -------------------------------------------------------------

# -------evaluate a model using k-fold cross-validation--------
def evaluate_model(X_train, y_Train, n_folds=5):

    accuracy, data = list(), list()

    # prepare 5-cross validation
    kfold = KFold(n_folds, shuffle=True, random_state=1)

    for x_train, x_test in kfold.split(X_train):
        # create model
        model = create_model()
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[x_train], y_Train[x_train], X_train[x_test], y_Train[x_test]
        # fit model
        data_fit = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=10, batch_size=32)
        # evaluate model
        _, acc = model.evaluate(testX, testY, verbose=0)
        # stores accuracy
        accuracy.append(acc)
        data.append(data_fit)
    return accuracy, data

# %%
# plot diagnostic learning curves
def summarize_diagnostics(data):
    for i in range(len(data)):
        # plot loss
        pyplot.subplot(2, 1, 1)
        pyplot.title('Cross Entropy Loss')
        pyplot.plot(data[i].history['loss'], color='red', label='green')
        pyplot.plot(data[i].history['val_loss'], color='orange', label='test')
        # plot accuracy
        pyplot.subplot(2, 1, 2)
        pyplot.title('Classification Accuracy')
        pyplot.plot(data[i].history['accuracy'], color='blue', label='train')
        pyplot.plot(data[i].history['val_accuracy'], color='orange', label='test')
    pyplot.show()

# %%
# summarize model performance
def summarize_performance(acc):
    # print summary
    print('Accuracy: mean=%.3f std=%.3f, n=%d' % (numpy.mean(acc) * 100, numpy.std(acc) * 100, len(acc)))

    # box and whisker plots of results
    pyplot.boxplot(acc)
    pyplot.show()

# %%
# This function predicts the images already in the dataset
def test(X_train, model):
    test_images = X_train[1:5]
    test_images = test_images.reshape(test_images.shape[0], 28, 28)

    for i, test_image in enumerate(test_images, start=1):
        org_image = test_image
        test_image = test_image.reshape(1, 28, 28, 1)
        prediction = model.predict_classes(test_image, verbose=0)

        print("Predicted digit: {}".format(prediction[0]))
        plt.subplot(220 + i)
        plt.axis('off')
        plt.title("Predicted digit: {}".format(prediction[0]))
        plt.imshow(org_image, cmap=plt.get_cmap('gray'))

    plt.show()

# %%
def run():
    X_test, y_test, X_train, y_train = input_data()

    # Evaluate
    accuracy, data = evaluate_model(X_train, y_train)
    summarize_diagnostics(data)
    summarize_performance(accuracy)
    model = create_model()
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200)
    # TEST
    # for images alreday
    test(X_train, model)

    # serialize model to JSON
    model_json = model.to_json()
    with open("model.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights("model.h5")
    print("Saved model to disk")




run()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.1250 - accuracy: 0.9613 - val_loss: 0.0680 - val_accuracy: 0.9784
# Epoch 2/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0442 - accuracy: 0.9861 - val_loss: 0.0533 - val_accuracy: 0.9843
# Epoch 3/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.0412 - val_accuracy: 0.9878
# Epoch 4/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0208 - accuracy: 0.9928 - val_loss: 0.0580 - val_accuracy: 0.9851
# Epoch 5/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.0376 - val_accuracy: 0.9892
# Epoch 6/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.0416 - val_accuracy: 0.9878
# Epoch 7/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.0450 - val_accuracy: 0.9894
# Epoch 8/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0700 - val_accuracy: 0.9865
# Epoch 9/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0537 - val_accuracy: 0.9889
# Epoch 10/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0725 - val_accuracy: 0.9879
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_21 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.1217 - accuracy: 0.9623 - val_loss: 0.0525 - val_accuracy: 0.9845
# Epoch 2/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0448 - accuracy: 0.9866 - val_loss: 0.0508 - val_accuracy: 0.9839
# Epoch 3/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0303 - accuracy: 0.9901 - val_loss: 0.0448 - val_accuracy: 0.9863
# Epoch 4/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0228 - accuracy: 0.9930 - val_loss: 0.0491 - val_accuracy: 0.9865
# Epoch 5/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0491 - val_accuracy: 0.9871
# Epoch 6/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0400 - val_accuracy: 0.9888
# Epoch 7/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.0512 - val_accuracy: 0.9876
# Epoch 8/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.0435 - val_accuracy: 0.9902
# Epoch 9/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.0481 - val_accuracy: 0.9886
# Epoch 10/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0500 - val_accuracy: 0.9882
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.1211 - accuracy: 0.9625 - val_loss: 0.0566 - val_accuracy: 0.9824
# Epoch 2/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0448 - accuracy: 0.9860 - val_loss: 0.0497 - val_accuracy: 0.9851
# Epoch 3/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0294 - accuracy: 0.9904 - val_loss: 0.0414 - val_accuracy: 0.9895
# Epoch 4/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0227 - accuracy: 0.9929 - val_loss: 0.0396 - val_accuracy: 0.9890
# Epoch 5/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0182 - accuracy: 0.9939 - val_loss: 0.0403 - val_accuracy: 0.9887
# Epoch 6/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0145 - accuracy: 0.9950 - val_loss: 0.0590 - val_accuracy: 0.9861
# Epoch 7/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0477 - val_accuracy: 0.9889
# Epoch 8/10
# 1500/1500 [==============================] - 23s 16ms/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0563 - val_accuracy: 0.9890
# Epoch 9/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0501 - val_accuracy: 0.9896
# Epoch 10/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0566 - val_accuracy: 0.9888
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.1246 - accuracy: 0.9617 - val_loss: 0.0552 - val_accuracy: 0.9834
# Epoch 2/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0477 - accuracy: 0.9854 - val_loss: 0.0366 - val_accuracy: 0.9893
# Epoch 3/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0323 - accuracy: 0.9900 - val_loss: 0.0431 - val_accuracy: 0.9875
# Epoch 4/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0245 - accuracy: 0.9919 - val_loss: 0.0321 - val_accuracy: 0.9902
# Epoch 5/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0190 - accuracy: 0.9941 - val_loss: 0.0382 - val_accuracy: 0.9898
# Epoch 6/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0392 - val_accuracy: 0.9901
# Epoch 7/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0493 - val_accuracy: 0.9873
# Epoch 8/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0381 - val_accuracy: 0.9910
# Epoch 9/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0393 - val_accuracy: 0.9919
# Epoch 10/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.0519 - val_accuracy: 0.9883
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.1258 - accuracy: 0.9603 - val_loss: 0.0616 - val_accuracy: 0.9816
# Epoch 2/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0449 - accuracy: 0.9862 - val_loss: 0.0446 - val_accuracy: 0.9856
# Epoch 3/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0314 - accuracy: 0.9902 - val_loss: 0.0417 - val_accuracy: 0.9880
# Epoch 4/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 0.0457 - val_accuracy: 0.9879
# Epoch 5/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0440 - val_accuracy: 0.9891
# Epoch 6/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0138 - accuracy: 0.9957 - val_loss: 0.0439 - val_accuracy: 0.9887
# Epoch 7/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.0374 - val_accuracy: 0.9902
# Epoch 8/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 0.0548 - val_accuracy: 0.9884
# Epoch 9/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0396 - val_accuracy: 0.9910
# Epoch 10/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0410 - val_accuracy: 0.9908
# Accuracy: mean=98.880 std=0.102, n=5
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.1891 - accuracy: 0.9424 - val_loss: 0.0563 - val_accuracy: 0.9813
# Epoch 2/10
# 300/300 [==============================] - 20s 68ms/step - loss: 0.0492 - accuracy: 0.9851 - val_loss: 0.0502 - val_accuracy: 0.9854
# Epoch 3/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0330 - accuracy: 0.9897 - val_loss: 0.0328 - val_accuracy: 0.9892
# Epoch 4/10
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0245 - accuracy: 0.9921 - val_loss: 0.0305 - val_accuracy: 0.9903
# Epoch 5/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0317 - val_accuracy: 0.9901
# Epoch 6/10
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0324 - val_accuracy: 0.9914
# Epoch 7/10
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0334 - val_accuracy: 0.9910
# Epoch 8/10
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0355 - val_accuracy: 0.9911
# Epoch 9/10
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0309 - val_accuracy: 0.9911
# Epoch 10/10
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0305 - val_accuracy: 0.9911
# Predicted digit: 0
# Predicted digit: 4
# Predicted digit: 1
# Predicted digit: 9
# Saved model to disk
